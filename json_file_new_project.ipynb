# %%
import pandas as pd 
import numpy as np

# %%
import json 
from pandas.io.json import json_normalize

# %% [markdown]
# <B>TASK1: FLATTEN THE FILE BELOW </B>

# %%
text = {
    'Geeks': [
        {
            'Geekname': 'Sahil Kumar', 
            'subject': 'Data structures', 
            'Articles': 10
        },
        {
            'Geekname': 'Pawan singh',
            'subject': 'Algorithms', 
            'Articles': 16
        }, 
        {
            'Geekname': 'Ayush Goel', 
            'subject': 'Networking', 
            'Articles': 7
        }
    ],
    
    'marlians': {'name1': 'Tuface', 'name2': 'Tiwa', 'name3': 'Tupace'}   
}

# %%
json_file = json.dumps(text)

# %%
json_file_new = json.loads(json_file)

# %%
##file = pd.read_json('https://github.com/a9k00r/python-test/blob/master/raw_nyc_phil.json')
pd.read_json('https://raw.githubusercontent.com/chrisalbon/simulated_datasets/master/data.json', orient = 'values')
# Out:
#     integer            datetime  category
# 0         5 2015-01-01 00:00:00         0
# 1         5 2015-01-01 00:00:01         0
# 2         9 2015-01-01 00:00:02         0
# 3         6 2015-01-01 00:00:03         0
# 4         6 2015-01-01 00:00:04         0
# ..      ...                 ...       ...
# 95        9 2015-01-01 00:01:35         0
# 96        8 2015-01-01 00:01:36         0
# 97        6 2015-01-01 00:01:37         0
# 98        8 2015-01-01 00:01:38         0
# 99        1 2015-01-01 00:01:39         0
#
# [100 rows x 3 columns]

# %%
#Read json file into python
file = pd.read_json('https://raw.githubusercontent.com/a9k00r/python-test/master/raw_nyc_phil.json', orient = 'columns')
file.head()
# Out:
#                                             programs
# 0  {'season': '1842-43', 'orchestra': 'New York P...
# 1  {'season': '1842-43', 'orchestra': 'New York P...
# 2  {'season': '1842-43', 'orchestra': 'Musicians ...
# 3  {'season': '1842-43', 'orchestra': 'New York P...
# 4  {'season': '1843-44', 'orchestra': 'New York P...

# %%
#initial dimension
file.shape
# Out:
# (13954, 1)

# %%
json_normalize(data = file['programs'])
# Out:
#         season                                 orchestra  \
# 0      1842-43                     New York Philharmonic
# 1      1842-43                     New York Philharmonic
# 2      1842-43  Musicians from the New York Philharmonic
# 3      1842-43                     New York Philharmonic
# 4      1843-44                     New York Philharmonic
# ...        ...                                       ...
# 13949  2016-17  Musicians from the New York Philharmonic
# 13950  2016-17                     New York Philharmonic
# 13951  2016-17                     New York Philharmonic
# 13952  2016-17                     New York Philharmonic
# 13953  2016-17                     New York Philharmonic
#
#                                                 concerts programID  \
# 0      [{'Date': '1842-12-07T05:00:00Z', 'eventType':...      3853
# 1      [{'Date': '1843-02-18T05:00:00Z', 'eventType':...      5178
# 2      [{'Date': '1843-04-07T05:00:00Z', 'eventType':...     10785
# ...

# %%
#showing the concerts data
json_normalize(data = file['programs'], record_path = 'concerts', meta = ['programID','orchestra'])
# Out:
#                        Date                      eventType  \
# 0      1842-12-07T05:00:00Z            Subscription Season
# 1      1843-02-18T05:00:00Z            Subscription Season
# 2      1843-04-07T05:00:00Z                        Special
# 3      1843-04-22T05:00:00Z            Subscription Season
# 4      1843-11-18T05:00:00Z            Subscription Season
# ...                     ...                            ...
# 21602  2017-06-24T04:00:00Z                        Chamber
# 21603  2017-07-02T04:00:00Z                           Tour
# 21604  2017-07-03T04:00:00Z                           Tour
# 21605  2017-07-04T04:00:00Z  Tour - Young People's Concert
# 21606  2017-07-07T04:00:00Z                           Tour
#
#                                       Venue          Location    Time  \
# 0                              Apollo Rooms     Manhattan, NY  8:00PM
# 1                              Apollo Rooms     Manhattan, NY  8:00PM
# ...

# %%
#showing the works data
json_normalize(data = file['programs'], record_path = ['works', 'soloists'], meta = ['programID','orchestra'])
# Out:
#                                              soloistName soloistRoles  \
# 0                                       Otto, Antoinette            S
# 1                                  Scharfenberg, William            A
# 2                                    Hill, Ureli Corelli            A
# 3                                         Derwort, G. H.            A
# 4                                        Boucher, Alfred            A
# ...                                                  ...          ...
# 56189                                         Xu, Weiqin            S
# 56190                                Martin, Christopher            S
# 56191                                     Shryock, Grace            S
# 56192  Jazz at Lincoln Center Orchestra with Wynton M...            S
# 56193  Jazz at Lincoln Center Orchestra with Wynton M...            S
#
#       soloistInstrument programID              orchestra
# 0               Soprano      3853  New York Philharmonic
# ...

# %% [markdown]
# <b>TASK 2: FLATTEN THE JSON FILE BELOW</b>

# %%
data1 = {
"header": {
"type": "esummary",
"version": "0.3"
},
"result": {
"12967": {
"uid": "12967",
"pubdate": "1976 Dec 11",
"epubdate": "",
"source": "Eur J Biochem",
"authors": [
{
"name": "Giannini I",
"authtype": "Author",
"clusterid": ""
},
{
"name": "Baroncelli V",
"authtype": "Author",
"clusterid": ""
},
{
"name": "Boccalon G",
"authtype": "Author",
"clusterid": ""
},
{
"name": "Fasella P",
"authtype": "Author",
"clusterid": ""
}
],
"lastauthor": "Fasella P",
"title": "Kinetics of the interaction between aspartic aminotransferase and anions.",
"sorttitle": "kinetics of the interaction between aspartic aminotransferase and anions",
"volume": "71",
"issue": "2",
"pages": "475-81",
"lang": [
"eng"
],
"nlmuniqueid": "0107600",
"issn": "0014-2956",
"essn": "1432-1033",
"pubtype": [
"Journal Article"
],
"recordstatus": "PubMed - indexed for MEDLINE",
"pubstatus": "4",
"articleids": [
{
"idtype": "pubmed",
"idtypen": 1,
"value": "12967"
},
{
"idtype": "doi",
"idtypen": 3,
"value": "10.1111/j.1432-1033.1976.tb11136.x"
},
{
"idtype": "rid",
"idtypen": 8,
"value": "12967"
},
{
"idtype": "eid",
"idtypen": 8,
"value": "12967"
}
],
"history": [
{
"pubstatus": "pubmed",
"date": "1976/12/11 00:00"
},
{
"pubstatus": "medline",
"date": "1976/12/11 00:01"
},
{
"pubstatus": "entrez",
"date": "1976/12/11 00:00"
}
],
"references": [],
"attributes": [
"Has Abstract"
],
"pmcrefcount": "",
"fulljournalname": "European journal of biochemistry",
"elocationid": "",
"doctype": "citation",
"srccontriblist": [],
"booktitle": "",
"medium": "",
"edition": "",
"publisherlocation": "",
"publishername": "",
"srcdate": "",
"reportnumber": "",
"availablefromurl": "",
"locationlabel": "",
"doccontriblist": [],
"docdate": "",
"bookname": "",
"chapter": "",
"sortpubdate": "1976/12/11 00:00",
"sortfirstauthor": "Giannini I",
"vernaculartitle": ""
},
"uids": [
"12967"
]
}
}

# %%
json_file_1 = json.dumps(data1)

# %%
python_file_1 = json.loads(json_file_1)

# %%
df = json_normalize(data = python_file_1['result']['12967'], record_path = ['authors'])#, record_path = [['12967'], 'articleids'], ['12967', 'authors']])

# %%
df.head(20)
# Out:
#   authtype clusterid          name
# 0   Author              Giannini I
# 1   Author            Baroncelli V
# 2   Author              Boccalon G
# 3   Author               Fasella P

# %% [markdown]
# <b>TASK 3: FLATTEN THE FILE BELOW </b>

# %%
data = [{'state': 'Florida',
          'shortname': 'FL',
          'info': {
               'governor': 'Rick Scott'
          },
          'counties': [{'name': 'Dade', 'population': 12345},
                      {'name': 'Broward', 'population': 40000},
                      {'name': 'Palm Beach', 'population': 60000}]},
         {'state': 'Ohio',
          'shortname': 'OH',
          'info': {
               'governor': 'John Kasich'
          },
          'counties': [{'name': 'Summit', 'population': 1234},
                       {'name': 'Cuyahoga', 'population': 1337}]}]

# %%
result = json_normalize(data, 'counties', ['state', 'shortname',
                                           ['info', 'governor']])

# %%
result.head()
# Out:
#          name  population    state shortname info.governor
# 0        Dade       12345  Florida        FL    Rick Scott
# 1     Broward       40000  Florida        FL    Rick Scott
# 2  Palm Beach       60000  Florida        FL    Rick Scott
# 3      Summit        1234     Ohio        OH   John Kasich
# 4    Cuyahoga        1337     Ohio        OH   John Kasich
